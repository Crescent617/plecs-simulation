# %% [markdown]
# # DAB直流母线电压上升——波形分析

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc

# rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
# ## for Palatino and other serif fonts use:
# #rc('font',**{'family':'serif','serif':['Palatino']})
# rc('text', usetex=True)

# plt.style.use('seaborn-muted')
sns.set(style='white')

# %%
df = pd.read_csv('./data_with_ls.csv', index_col=0)

# %%
df
# Out:
#                  Vm1         Vm4         Vm5         Vm2
# Time
# 0.008198  760.897161 -699.997428 -758.685239 -729.720468
# 0.008198  760.897122 -700.000061 -754.854077 -727.805968
# 0.008198  760.897081 -700.002246 -749.143366 -724.951471
# 0.008198  760.897038 -700.003909 -741.747190 -721.253979
# 0.008198  760.897002 -700.004842 -734.704857 -717.733091
# ...              ...         ...         ...         ...
# 0.008280  761.168819 -699.746219 -761.432437 -730.978542
# 0.008280  761.169696 -699.749450 -761.429956 -730.979112
# 0.008280  761.170561 -699.752680 -761.427462 -730.979671
# 0.008280  761.171413 -699.755910 -761.424953 -730.980221
# 0.008280  761.172252 -699.759142 -761.422432 -730.980764
#
# [3100 rows x 4 columns]

# %%
df1 = df.iloc[:len(df), :].drop(columns='Vm2')

# %%
title = 'Waves'
dpi = 175

fig, axes = plt.subplots(2, 1, dpi=dpi, figsize=(10,7), sharex=True)
# axes[0].set(title=title+'\n')
axes[-1].set(xlabel=f'\n$Time (s)$')

x = df1.index
voltage, current = axes
v1, v2, i1 = df1

voltage.plot(x, df1[v1], 'b', label='$v_{ab}$', linewidth=1.5)
voltage.plot(x, df1[v2], 'r', label='$v_{cd}$', linewidth=1.5)
voltage.grid(True)
voltage.legend()
voltage.set(ylabel=f'$Voltage (V)$')#, xticks=[])

current.plot(x, df1[i1], 'g', label='$I_{L}$', linewidth=1.5)
current.grid(True)
current.legend()
current.set(ylabel=f'$Current (A)$')#, xticks=[])

sns.despine()
# # plt.grid(True)
plt.tight_layout()

# %%
title = 'Waves'
dpi = 175

fig = plt.figure(dpi=dpi, figsize=(8,6))
# axes[0].set(title=title+'\n')

x = df1.index
v1, v2 = 'Vm4', 'Vm5'

plt.subplot(211)
plt.plot(x, df1[v1], 'b', label='$U_{ab}/V$', linewidth=1.5)
plt.ylabel('$U_{ab}/V$')#, xticks=[])
plt.xticks([])
plt.grid(True)

plt.subplot(212)
plt.plot(x, df1[v2], 'r', label='$U_{cd}/V$', linewidth=1.5)
plt.ylabel('$U_{cd}/V$')#, xticks=[])
plt.grid(True)
plt.xlabel(f'\n$t/s$')
# plt.legend()

plt.tight_layout()

# %%
plt.subplot?
